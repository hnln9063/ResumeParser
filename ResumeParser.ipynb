# %%
pip install pyresparser
# Out:
# Collecting pyresparser
#   Downloading pyresparser-1.0.6-py3-none-any.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (23.2.0)
# Requirement already satisfied: blis>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (0.7.11)
# Requirement already satisfied: certifi>=2019.6.16 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2023.11.17)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (5.2.0)
# Requirement already satisfied: cymem>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.0.8)
# Collecting docx2txt>=0.7 (from pyresparser)
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (3.6)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (4.19.2)
# Requirement already satisfied: nltk>=3.4.3 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (3.8.1)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (1.5.3)
# Collecting pdfminer.six>=20181108 (from pyresparser)
#   Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: preshed>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (3.0.9)
# Collecting pycryptodome>=3.8.2 (from pyresparser)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.8 MB/s eta 0:00:00
# Collecting pyrsistent>=0.15.2 (from pyresparser)
#   Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: pytz>=2019.1 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2023.3.post1)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.31.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (1.16.0)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.4.0)
# Requirement already satisfied: spacy>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (3.6.1)
# Requirement already satisfied: srsly>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.4.8)
# Requirement already satisfied: thinc>=7.0.4 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (8.1.12)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (4.66.1)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (2.0.7)
# Requirement already satisfied: wasabi>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from pyresparser) (1.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->pyresparser) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->pyresparser) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->pyresparser) (0.17.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.3->pyresparser) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.3->pyresparser) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.3->pyresparser) (2023.6.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20181108->pyresparser) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20181108->pyresparser) (42.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from preshed>=2.0.1->pyresparser) (1.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.4->pyresparser) (3.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc>=7.0.4->pyresparser) (0.1.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20181108->pyresparser) (1.16.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy>=2.1.4->pyresparser) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.4->pyresparser) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.1.4->pyresparser) (2.1.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20181108->pyresparser) (2.21)
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=d6b93606b13c1a24992f02f70a0f814e9a4cd8158fa4afad6150619dbc195e4e
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# Installing collected packages: docx2txt, pyrsistent, pycryptodome, pdfminer.six, pyresparser
# Successfully installed docx2txt-0.8 pdfminer.six-20231228 pycryptodome-3.20.0 pyresparser-1.0.6 pyrsistent-0.20.0

# %%
pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.7 MB/s eta 0:00:00
# Collecting pdfminer.six==20221105 (from pdfplumber)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (9.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.26.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber) (42.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20231228
#     Uninstalling pdfminer.six-20231228:
#       Successfully uninstalled pdfminer.six-20231228
# Successfully installed pdfminer.six-20221105 pdfplumber-0.10.3 pypdfium2-4.26.0

# %%
import pdfplumber

def parse_resume(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text()

    return text

# Example usage
pdf_path = '/content/sample_data/HNLakshmiNarasimha_Resume.pdf'
resume_text = parse_resume(pdf_path)

print(resume_text)
# Out:
# LAKSHMI NARASIMHA H N
# Hindupur, Andhra Pradesh
# (cid:131) +91 9063400455 # hnlakshminarasimha1@gmail.com (cid:239) linkedin.com/in/lakshmi-narasimha-hn
# EDUCATION
# G Pulla Reddy Engineering College Dec 2020 - Apr 2024
# Bachelor of Technology in Computer Science and Engineering CGPA: 9.01 Andhra Pradesh
# Narayana Junior College Jun 2018 - Mar 2020
# Intermediate Education in MPC stream Marks: 966/1000 Telangana
# EXPERIENCE
# Kodnest May 2023 – July 2023
# Java Full Stack Developer Intern Remote
# • Developed proficiency in HTML, CSS and Javascript ensuring responsiveness and user-friendly interfaces.
# • Demonstrated strong understanding of database connectivity by designing and optimizing SQL queries, resulting in
# enhanced data retrieval and storage.
# • Skills Gained: Java, HTML, CSS, Javascript, JavaServlets, Database Connectivity, SQL
# PROJECT
# College Quiz Website | Spring Boot, Spring JPA, HTML/CSS, Thymeleaf, Javascript, MySQL | Source Code
# • Developed a user-friendly College Quiz Application featuring role-specific interfaces for faculty and students, enhancing
# the educational experience.
# • Empowered faculty with quiz creation and adding updates functionalities, and result tracking based on the average of the
# top 3 scores.
# • Enhanced student engagement through scheduled quiz access, anti-copy measures, and a comprehensive dashboard
# featuring diverse learning paths.
# SKILLS
# Languages: Java, Python, C, HTML/CSS, JavaScript, SQL
# Version Control: Git, GitHub
# Tools: Eclipse, Spring Tool Suite, VisualStudio Code, Figma
# Operating System: Unix/Linux, Windows
# Soft Skills: Adaptability, Communication, Problem Solving
# CERTIFICATIONS
# Java | Link Oct 2022 – Feb 2023
# Certified from EPAM Systems through COE program
# Python | Link Sep 2021 – Nov 2021
# Certified from Internshala
# ACHIEVEMENTS
# • Published and improved multiple articles in GeeksForGeeks portal. (Articles)
# • Received a contributor badge from GeeksForGeeks. (Badge)
# • Solved more than 400+ problems across platforms.
# • Successfully completed 2 comprehensive courses i.e., Artificial Intelligence and Cloud Computing through the Wipro
# FutureSkills program.
# CODING PROFILES
# • Acquired a highest CodeChef rating of 1369 and solved 125+ problems. | CodeChef
# • Tackled 300+ problems, achieving a notable POTD streak of 100 days. | GeeksForGeeks
# • Effectively resolved 50+ problems. | LeetCode
# • Secured a problem-solving badge, showcasing a 4-star rating. | HackerRank

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.4)

# %%
pip install spacy[en_core_web_sm]
# Out:
# Requirement already satisfied: spacy[en_core_web_sm] in /usr/local/lib/python3.10/dist-packages (3.6.1)
# WARNING: spacy 3.6.1 does not provide the extra 'en_core_web_sm'
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy[en_core_web_sm]) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy[en_core_web_sm]) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[en_core_web_sm]) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[en_core_web_sm]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[en_core_web_sm]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[en_core_web_sm]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[en_core_web_sm]) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy[en_core_web_sm]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy[en_core_web_sm]) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy[en_core_web_sm]) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy[en_core_web_sm]) (2.1.4)

# %%
import spacy

def extract_skills(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    skills = set()

    for token in doc:
        # Check if the token is a skill (you can customize this based on your needs)
        if token.text.lower() in [
        "python", "java", "javascript", "machine learning", "data analysis",
        "c", "c++", "ruby", "swift", "kotlin", "php", "go", "typescript",
        "html", "css", "react", "angular", "vue.js", "node.js", "django",
        "flask", "bootstrap", "express.js", "spring boot", "ruby on rails",
        "flutter", "android", "ios", "swift", "kotlin", "sql", "mysql",
        "postgresql", "mongodb", "sqlite", "oracle", "aws", "azure", "google cloud platform",
        "docker", "kubernetes", "jenkins", "ansible", "terraform", "git",
        "github", "gitlab", "bitbucket", "object-oriented programming", "functional programming",
        "procedural programming", "bash", "powershell", "tcp/ip", "http/https", "dns",
        "ssl/tls", "cybersecurity", "encryption", "penetration testing", "security auditing",
        "machine learning", "data analysis", "pandas", "numpy", "scipy",
        "visual studio code", "intellij idea", "eclipse", "pycharm", "unit testing",
        "integration testing", "selenium", "junit", "travis ci", "circleci", "jenkins",
        "gitlab ci/cd", "scrum", "kanban", "jira", "agile methodologies", "linux",
        "windows", "macos", "restful", "graphql", "raspberry pi", "arduino", "mqtt"]:
            skills.add(token.text)
    return skills

# Example usage
resume_skills = list(extract_skills(resume_text))

print("Skills:", resume_skills)
# Out:
# Skills: ['MySQL', 'JavaScript', 'Python', 'CSS', 'Eclipse', 'SQL', 'Javascript', 'C', 'Java', 'Windows', 'GitHub', 'Git', 'HTML', 'Linux']

# %%
pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: google-ai-generativelanguage==0.4.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.4.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.17.3)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.5.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.4.0->google-generativeai) (1.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.62.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (4.9)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.60.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.48.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth->google-generativeai) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2023.11.17)

# %%
import google.generativeai as palm

# %%
palm.configure(api_key='Your_API_KEY')

# %%
for i in range(len(resume_skills)):
  reply = palm.chat(context="Generate 2 hard level interview questions with correct answer immediately after every question for the given topics. ", messages='Generate interview related questions about' +resume_skills[i]+ 'along with correct answer immediately after every question. Provide detailed explaination. Dont give questions like what is HTML, What is Eclipse etc..', temperature=0)
  print(reply.last)
# Out:
# 1. What is the difference between a primary key and a unique key?
#
# A primary key is a column or set of columns that uniquely identifies each row in a table. A unique key is a column or set of columns that cannot contain duplicate values, but does not necessarily need to uniquely identify each row.
#
# 2. What is the difference between a clustered index and a non-clustered index?
#
# A clustered index is a special type of index that stores the data rows in the table in the same order as the index keys. A non-clustered index is a type of index that stores the data rows in the table in a different order than the index keys.
#
# 3. What is the difference between a full table scan and an index scan?
#
# A full table scan is a type of query execution plan that reads all of the rows in a table to find the rows that match the query criteria. An index scan is a type of query execution plan that reads only the rows in the table that are stored in the index that is used to satisfy the query criteria.
#
# 4. What is the difference between a MyISAM table and an InnoDB table?
#
# A MyISAM table is a type of table that uses a table-level locking mechanism. An InnoDB table is a type of table that uses a row-level locking mechanism.
#
# 5. What is the difference between a transaction and a savepoint?
#
# A transaction is a unit of work that is either committed or rolled back. A savepoint is a point in time within a transaction that can be used to roll back the transaction to that point.
#
# 6. What is the difference between a stored procedure and a function?
#
# A stored procedure is a set of SQL statements that can be called from within another SQL statement. A function is a set of SQL statements that can be called from within another SQL statement, but it also returns a value.
#
# 7. What is the difference between a view and a materialized view?
#
# A view is a virtual table that is defined in terms of other tables. A materialized view is a physical table that is created from the results of a view definition.
#
# 8. What is the difference between a trigger and an event?
#
# A trigger is a stored procedure that is executed when an event occurs on a table. An event is a notification that is sent to a subscriber when an event occurs on a table.
#
# 9. What is the difference between a replication slave and a replication master?
#
# A replication slave is a database that receives data from a replication master. A replication master is a database that sends data to a replication slave.
#
# 10. What is the difference between a MySQL Cluster and a MySQL Replication?
#
# A MySQL Cluster is a high-availability, scalable, and fault-tolerant database solution. A MySQL Replication is a database replication solution that allows you to create a copy of your database on another server.
#
# 11. What is the difference between a MySQL Instance and a MySQL Server?
#
# A MySQL Instance is a running copy of the MySQL software. A MySQL Server is a computer that runs the MySQL software.
#
# 12. What is the difference between a MySQL Client and a MySQL Server?
#
# A MySQL Client is a program that connects to a MySQL Server and executes SQL statements. A MySQL Server is a program that accepts connections from MySQL Clients and executes SQL statements.
#
# 13. What is the difference between a MySQL User and a MySQL Role?
#
# A MySQL User is an account that has permission to connect to a MySQL Server. A MySQL Role is a set of permissions that can be assigned to a MySQL User.
#
# 14. What is the difference between a MySQL Database and a MySQL Table?
#
# A MySQL Database is a collection of MySQL Tables. A MySQL Table is a collection of rows and columns.
#
# 15. What is the difference between a MySQL Row and a MySQL Column?
#
# A MySQL Row is a single record in a MySQL Table. A MySQL Column is a single field in a MySQL Table.
# Sure, here are two hard level interview questions about JavaScript, along with the correct answer immediately after each question:
#
# 1. What is the difference between a closure and a lexical environment?
#
# A closure is a function that has access to variables that are defined in its enclosing scope, even if those variables are no longer accessible from the enclosing scope. A lexical environment is a region of memory that contains variables and their values. When a function is created, it is assigned to a lexical environment. The variables that are defined in the function's lexical environment are accessible from within the function, even if those variables are no longer accessible from the enclosing scope.
#
# 2. What is the difference between a prototype and an instance?
#
# A prototype is a blueprint for creating new objects. An instance is an object that is created from a prototype. When you create a new object, you are actually creating a new instance of the object's prototype. The prototype of an object contains the object's properties and methods.
#
# Here are some additional details about closures and lexical environments:
#
# * Closures are created when a function is created. The closure contains a reference to the variables that are defined in the function's enclosing scope. This means that the function can access those variables, even if those variables are no longer accessible from the enclosing scope.
# * Lexical environments are created when a function is created. The lexical environment contains a reference to the function's variables and their values. This means that the function can access its variables and their values, even if those variables are no longer accessible from the enclosing scope.
#
# Here are some additional details about prototypes and instances:
#
# * Prototypes are created when a new object is created. The prototype of an object contains the object's properties and methods.
# * Instances are created when a new object is created from a prototype. When you create a new object, you are actually creating a new instance of the object's prototype. This means that the new object will have the same properties and methods as the object's prototype.
# Sure, here are two hard level interview questions about Python, along with the correct answer immediately after each question:
#
# 1. What is the difference between a list and a tuple in Python?
#
# A list is a mutable sequence, while a tuple is an immutable sequence. This means that you can change the elements of a list, but you cannot change the elements of a tuple.
#
# For example, the following code creates a list and a tuple:
#
# ```python
# >>> list = [1, 2, 3]
# >>> tuple = (1, 2, 3)
# ```
#
# You can change the elements of the list, but not the elements of the tuple:
#
# ```python
# >>> list[0] = 4
# >>> list
# [4, 2, 3]
# >>> tuple[0] = 4
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: 'tuple' object does not support item assignment
# ```
#
# 2. What is the difference between a function and a method in Python?
#
# A function is a reusable block of code that can be called multiple times. A method is a function that is associated with an object.
#
# For example, the following code defines a function and a method:
#
# ```python
# def add_numbers(x, y):
#     return x + y
#
# class MyClass:
#     def add_numbers(self, x, y):
#         return x + y
# ```
#
# The `add_numbers` function can be called with any two numbers, and it will return the sum of those numbers. The `add_numbers` method can only be called on objects of the `MyClass` class, and it will return the sum of the two numbers passed to it.
#
# I hope these questions were helpful!
# 1. What is the difference between a block element and an inline element?
#
# A block element is an element that takes up the full width of its parent element, while an inline element is an element that takes up only as much space as its content.
#
# For example, a <div> is a block element, while a <span> is an inline element.
#
# 2. What is the difference between a relative and an absolute position?
#
# A relative position is a position that is relative to the position of its parent element, while an absolute position is a position that is absolute to the viewport.
#
# For example, if you have a <div> with a relative position, and you set its top property to 10px, it will be positioned 10px from the top of its parent element.
#
# If you have a <div> with an absolute position, and you set its top property to 10px, it will be positioned 10px from the top of the viewport.
#
# 3. What is the difference between a fixed and a sticky position?
#
# A fixed position is a position that is fixed to the viewport, while a sticky position is a position that is fixed to the viewport until it scrolls past a certain point.
#
# For example, if you have a <div> with a fixed position, it will always be visible on the page, even if you scroll down.
#
# If you have a <div> with a sticky position, it will only be visible on the page until you scroll past a certain point, and then it will stick to the top of the viewport.
#
# 4. What is the difference between a display: block and a display: inline-block?
#
# A display: block element is an element that takes up the full width of its parent element, while a display: inline-block element is an element that takes up only as much space as its content, but is still treated as a block element.
#
# For example, a <div> is a display: block element, while a <span> is a display: inline-block element.
#
# 5. What is the difference between a float: left and a float: right?
#
# A float: left element is an element that is floated to the left of its parent element, while a float: right element is an element that is floated to the right of its parent element.
#
# For example, if you have a <div> with a float: left, it will be floated to the left of its parent element, and any elements that come after it in the HTML will be pushed down below it.
#
# If you have a <div> with a float: right, it will be floated to the right of its parent element, and any elements that come after it in the HTML will be pushed down below it.
#
# 6. What is the difference between a clear: left and a clear: right?
#
# A clear: left element is an element that clears the floats on the left side of its parent element, while a clear: right element is an element that clears the floats on the right side of its parent element.
#
# For example, if you have a <div> with a float: left, and you add a <div> with a clear: left after it, the <div> with the clear: left will clear the float on the left side of its parent element, and the <div> with the float: left will be pushed down below it.
#
# If you have a <div> with a float: right, and you add a <div> with a clear: right after it, the <div> with the clear: right will clear the float on the right side of its parent element, and the <div> with the float: right will be pushed down below it.
#
# 7. What is the difference between a z-index: 1 and a z-index: 100?
#
# A z-index: 1 element is an element that has a z-index of 1, while a z-index: 100 element is an element that has a z-index of 100.
#
# Elements with a higher z-index will be positioned on top of elements with a lower z-index.
#
# For example, if you have a <div> with a z-index: 1 and a <div> with a z-index: 100, the <div> with the z-index: 100 will be positioned on top of the <div> with the z-index: 1.
#
# 8. What is the difference between a font-family: Arial, sans-serif and a font-family: Helvetica, Arial, sans-serif?
#
# A font-family: Arial, sans-serif element is an element that uses the Arial font if it is available
# 1. What are the different types of views in Eclipse?
#
# Eclipse has a number of different views that can be used to view and edit your code. The most common views are the Package Explorer, the Navigator, the Outline, the Source, and the Problems view.
#
# The Package Explorer view shows you the packages and classes in your project. The Navigator view shows you the files and folders in your project. The Outline view shows you the structure of the class you are currently editing. The Source view shows you the code for the class you are currently editing. The Problems view shows you any errors or warnings that have been found in your code.
#
# 2. What are the different types of editors in Eclipse?
#
# Eclipse has a number of different editors that can be used to edit your code. The most common editors are the Java editor, the XML editor, and the HTML editor.
#
# The Java editor is used to edit Java code. The XML editor is used to edit XML code. The HTML editor is used to edit HTML code.
#
# 3. What are the different types of perspectives in Eclipse?
#
# Eclipse has a number of different perspectives that can be used to view and edit your code. The most common perspectives are the Java perspective, the XML perspective, and the HTML perspective.
#
# The Java perspective is used to view and edit Java code. The XML perspective is used to view and edit XML code. The HTML perspective is used to view and edit HTML code.
#
# 4. What are the different types of actions in Eclipse?
#
# Eclipse has a number of different actions that can be used to edit your code. The most common actions are the Cut action, the Copy action, and the Paste action.
#
# The Cut action cuts the selected text to the clipboard. The Copy action copies the selected text to the clipboard. The Paste action pastes the text from the clipboard to the current location.
#
# 5. What are the different types of commands in Eclipse?
#
# Eclipse has a number of different commands that can be used to edit your code. The most common commands are the Save command, the Compile command, and the Run command.
#
# The Save command saves the current file. The Compile command compiles the current file. The Run command runs the current file.
#
# 6. What are the different types of shortcuts in Eclipse?
#
# Eclipse has a number of different shortcuts that can be used to edit your code. The most common shortcuts are the Ctrl+C shortcut, the Ctrl+V shortcut, and the Ctrl+X shortcut.
#
# The Ctrl+C shortcut copies the selected text to the clipboard. The Ctrl+V shortcut pastes the text from the clipboard to the current location. The Ctrl+X shortcut cuts the selected text to the clipboard.
#
# 7. What are the different types of preferences in Eclipse?
#
# Eclipse has a number of different preferences that can be used to customize the IDE. The most common preferences are the General preferences, the Java preferences, and the XML preferences.
#
# The General preferences control the general appearance and behavior of the IDE. The Java preferences control the Java-specific settings of the IDE. The XML preferences control the XML-specific settings of the IDE.
#
# 8. What are the different types of plug-ins in Eclipse?
#
# Eclipse is a plug-in-based IDE, which means that it can be extended with new features by installing plug-ins. There are a number of different plug-ins available for Eclipse, including plug-ins for development, testing, and debugging.
#
# 9. What are the different types of resources in Eclipse?
#
# Eclipse has a number of different resources that can be used to store your code and other files. The most common resources are the workspace, the projects, and the folders.
#
# The workspace is the root directory for all of your Eclipse projects. The projects are the containers for your code and other files. The folders are the containers for your files.
#
# 10. What are the different types of tasks in Eclipse?
#
# Eclipse has a number of different tasks that can be used to manage your projects. The most common tasks are the build task, the run task, and the debug task.
#
# The build task builds your project. The run task runs your project. The debug task debugs your project.
# Sure, here are two hard level interview questions about SQL, along with the correct answer and a detailed explanation:
#
# 1. What is the difference between a clustered index and a nonclustered index?
#
# A clustered index is a way of organizing data on a table so that the data is stored in a specific order. This order is determined by the clustered index key, which is a column or set of columns that is used to identify each row in the table. The clustered index key is also the primary key for the table, unless the table has a composite primary key.
#
# A nonclustered index is a way of organizing data on a table so that the data is stored in a different order than the clustered index. This order is determined by the nonclustered index key, which is a column or set of columns that is used to identify each row in the table. The nonclustered index key is not the primary key for the table.
#
# The main difference between a clustered index and a nonclustered index is that the clustered index is stored on the table itself, while the nonclustered index is stored in a separate structure. This means that a clustered index can only have one key, while a nonclustered index can have multiple keys.
#
# Another difference between a clustered index and a nonclustered index is that the clustered index is used to determine the physical order of the data on the table, while the nonclustered index is used to speed up queries.
#
# 2. What is the difference between a primary key and a unique key?
#
# A primary key is a column or set of columns that uniquely identifies each row in a table. A unique key is a column or set of columns that cannot contain duplicate values.
#
# The main difference between a primary key and a unique key is that a primary key must be unique, while a unique key does not have to be unique.
#
# Another difference between a primary key and a unique key is that a primary key is used to enforce referential integrity, while a unique key is not used to enforce referential integrity.
#
# Referential integrity is a rule that ensures that the data in one table is consistent with the data in another table. For example, if a table has a primary key of `CustomerID`, then the `CustomerID` column in another table must be a foreign key that references the `CustomerID` column in the first table. This ensures that each customer in the second table has a corresponding customer in the first table.
#
# I hope this helps!
# Sure, here are 2 hard level interview questions about JavaScript with correct answer immediately after every question:
#
# 1. What is the difference between a closure and a lexical environment?
#
# A closure is a function that has access to variables that are defined in its enclosing scope. A lexical environment is a scope that is created when a function is defined. The variables that are defined in a lexical environment are accessible to all functions that are defined in that environment.
#
# 2. What is the difference between a prototype and an instance?
#
# A prototype is a blueprint for creating new objects. An instance is an object that is created from a prototype. The prototype of an object is used to determine the properties and methods that are available to that object.
#
# 3. What is the difference between a constructor and a function?
#
# A constructor is a special type of function that is used to create new objects. A function is a general-purpose type of function that can be used to perform any type of task.
#
# 4. What is the difference between a variable and a property?
#
# A variable is a named location in memory that can store a value. A property is a named attribute of an object. Variables are declared using the var keyword, while properties are declared using the dot notation.
#
# 5. What is the difference between a primitive and an object?
#
# A primitive is a basic data type, such as a number, string, or boolean. An object is a complex data type that can contain other data types, such as properties and methods.
#
# 6. What is the difference between a function declaration and a function expression?
#
# A function declaration is a statement that defines a function. A function expression is an expression that evaluates to a function. Function declarations are typically used to define global functions, while function expressions are typically used to define local functions.
#
# 7. What is the difference between a call and a reference?
#
# A call is an operation that executes a function. A reference is a variable that contains the address of a function. When you call a function, the function's code is executed. When you assign a reference to a function, the reference contains the address of the function's code.
#
# 8. What is the difference between a scope and a closure?
#
# A scope is a region of code in which variables are defined and accessible. A closure is a function that has access to variables that are defined in its enclosing scope.
#
# 9. What is the difference between a hoisting and a closure?
#
# Hoisting is a JavaScript feature that causes variables to be defined at the top of their scope, even if they are declared later in the code. A closure is a function that has access to variables that are defined in its enclosing scope.
#
# 10. What is the difference between a prototype and a constructor?
#
# A prototype is a blueprint for creating new objects. A constructor is a special type of function that is used to create new objects. The prototype of an object is used to determine the properties and methods that are available to that object.
#
# 11. What is the difference between a variable and a property?
#
# A variable is a named location in memory that can store a value. A property is a named attribute of an object. Variables are declared using the var keyword, while properties are declared using the dot notation.
#
# 12. What is the difference between a primitive and an object?
#
# A primitive is a basic data type, such as a number, string, or boolean. An object is a complex data type that can contain other data types, such as properties and methods.
#
# 13. What is the difference between a function declaration and a function expression?
#
# A function declaration is a statement that defines a function. A function expression is an expression that evaluates to a function. Function declarations are typically used to define global functions, while function expressions are typically used to define local functions.
#
# 14. What is the difference between a call and a reference?
#
# A call is an operation that executes a function. A reference is a variable that contains the address of a function. When you call a function, the function's code is executed. When you assign a reference to a function, the reference contains the address of the function's code.
#
# 15. What is the difference between a scope and a closure?
#
# A scope is a region of code in which variables are defined and accessible. A closure is a function that has access to variables that are defined in its enclosing scope.
# Sure, here are two hard level interview questions about C along with the correct answer immediately after each question:
#
# 1. What is the difference between a pointer and a reference?
#
# A pointer is a variable that stores the address of another variable. A reference is a variable that acts as an alias for another variable.
#
# 2. What is the difference between a function and a procedure?
#
# A function is a block of code that can be called from another part of the program. A procedure is a block of code that can be called from another part of the program, but it does not return a value.
#
# 3. What is the difference between a local variable and a global variable?
#
# A local variable is a variable that is only accessible within the function in which it is declared. A global variable is a variable that is accessible from all parts of the program.
#
# 4. What is the difference between a static variable and a dynamic variable?
#
# A static variable is a variable that is allocated on the stack. A dynamic variable is a variable that is allocated on the heap.
#
# 5. What is the difference between a primitive type and a reference type?
#
# A primitive type is a type that represents a basic value, such as an integer or a floating-point number. A reference type is a type that represents an object.
#
# 6. What is the difference between a value type and a reference type?
#
# A value type is a type that stores its value directly in memory. A reference type is a type that stores a reference to an object in memory.
#
# 7. What is the difference between a stack and a heap?
#
# The stack is a region of memory that is used to store local variables and function parameters. The heap is a region of memory that is used to store dynamic variables and objects.
#
# 8. What is the difference between a call stack and a heap?
#
# The call stack is a data structure that stores the current state of a function call. The heap is a region of memory that is used to store dynamic variables and objects.
#
# 9. What is the difference between a compiler and an interpreter?
#
# A compiler is a program that converts source code into machine code. An interpreter is a program that executes source code line by line.
#
# 10. What is the difference between a compiled language and an interpreted language?
#
# A compiled language is a language that is converted into machine code by a compiler. An interpreted language is a language that is executed line by line by an interpreter.
#
# 11. What is the difference between a static language and a dynamic language?
#
# A static language is a language that has a fixed type system. A dynamic language is a language that has a dynamic type system.
#
# 12. What is the difference between a strongly typed language and a weakly typed language?
#
# A strongly typed language is a language that enforces type safety. A weakly typed language is a language that does not enforce type safety.
#
# 13. What is the difference between a garbage collector and a reference counting system?
#
# A garbage collector is a program that automatically manages memory. A reference counting system is a program that tracks the number of references to an object and automatically deletes the object when there are no more references to it.
#
# 14. What is the difference between a linked list and an array?
#
# A linked list is a data structure that stores data in a linear fashion. An array is a data structure that stores data in a fixed-size block of memory.
#
# 15. What is the difference between a hash table and a binary search tree?
#
# A hash table is a data structure that stores data in a way that allows for fast lookups. A binary search tree is a data structure that stores data in a way that allows for fast insertions and deletions.
#
# 16. What is the difference between a bubble sort and a quicksort?
#
# A bubble sort is a sorting algorithm that works by repeatedly comparing adjacent elements and swapping them if they are in the wrong order. A quicksort is a sorting algorithm that works by partitioning the data into two halves and then recursively sorting the two halves.
#
# 17. What is the difference between a depth-first search and a breadth-first search?
#
# A depth-first search is a graph traversal algorithm that starts at a node and then explores all of the nodes that are connected to it before moving on to other nodes. A breadth-first search is a graph traversal algorithm that starts at a node and then explores all of the nodes that are connected to it in a level-by-level fashion.
#
# 18. What is the difference between a greedy algorithm and a dynamic programming algorithm?
#
# A greedy algorithm is an algorithm that makes the best choice at each step without considering the future. A dynamic programming algorithm is an algorithm that stores the results of subproblems so that they can be reused
# Sure, here are two hard level interview questions about Java, along with the correct answer immediately after each question:
#
# 1. What is the difference between a static and a non-static inner class?
#
# A static inner class is a class that is not associated with any instance of an outer class. It can be accessed directly using its fully qualified name, and it does not have access to any instance variables or methods of the outer class. A non-static inner class is a class that is associated with an instance of an outer class. It can only be accessed through an instance of the outer class, and it has access to all of the instance variables and methods of the outer class.
#
# 2. What is the difference between a final and a non-final variable?
#
# A final variable is a variable that cannot be changed after it has been initialized. A non-final variable can be changed after it has been initialized.
#
# 3. What is the difference between a primitive type and a reference type?
#
# A primitive type is a type that represents a basic value, such as an integer or a boolean. A reference type is a type that represents an object.
#
# 4. What is the difference between a method and a constructor?
#
# A method is a function that is defined inside a class. A constructor is a special type of method that is used to create new instances of a class.
#
# 5. What is the difference between an interface and an abstract class?
#
# An interface is a blueprint for a class. It defines the methods that a class must implement, but it does not provide any implementation for those methods. An abstract class is a class that cannot be instantiated. It can only be used as a base class for other classes.
#
# 6. What is the difference between inheritance and polymorphism?
#
# Inheritance is a mechanism that allows a class to inherit the properties and methods of another class. Polymorphism is a mechanism that allows a class to be used in multiple ways.
#
# 7. What is the difference between encapsulation and abstraction?
#
# Encapsulation is a mechanism that hides the implementation details of a class from its users. Abstraction is a mechanism that hides the details of a complex object from its users.
#
# 8. What is the difference between a package and a module?
#
# A package is a group of related classes. A module is a group of related packages.
#
# 9. What is the difference between a public, private, protected, and default access modifier?
#
# A public access modifier allows a class to be accessed from any other class. A private access modifier allows a class to be accessed only from within the class itself. A protected access modifier allows a class to be accessed from within the class itself and from any class that inherits from it. A default access modifier is the same as a protected access modifier, except that it is used for classes that are not declared in a package.
#
# 10. What is the difference between a static and a dynamic method?
#
# A static method is a method that is associated with a class, not with an instance of a class. A dynamic method is a method that is associated with an instance of a class.
#
# 11. What is the difference between a synchronized and an unsynchronized method?
#
# A synchronized method is a method that can only be executed by one thread at a time. An unsynchronized method is a method that can be executed by multiple threads at the same time.
#
# 12. What is the difference between a volatile and a non-volatile variable?
#
# A volatile variable is a variable that is guaranteed to be visible to all threads. A non-volatile variable is a variable that is not guaranteed to be visible to all threads.
#
# 13. What is the difference between a checked and an unchecked exception?
#
# A checked exception is an exception that must be declared in the throws clause of a method. An unchecked exception is an exception that does not need to be declared in the throws clause of a method.
#
# 14. What is the difference between a compile-time error and a runtime error?
#
# A compile-time error is an error that occurs when a program is compiled. A runtime error is an error that occurs when a program is executed.
#
# 15. What is the difference between a garbage collector and a finalizer?
#
# A garbage collector is a system that automatically reclaims memory that is no longer being used. A finalizer is a method that is called when an object is garbage collected.
#
# 16. What is the difference between a stack and a heap?
#
# A stack is a data structure that is used to store objects in a LIFO (last in, first out) order. A heap is a data structure that is used to store objects in a random order.
#
# 17. What is the difference between a linked list and an array?
#
# A linked list is a data structure that stores data
# 1. What is the difference between a process and a thread?
#
# A process is a heavyweight object that has its own address space, while a thread is a lightweight object that shares the address space of its parent process. Processes are more expensive to create and manage than threads, but they offer more isolation and security. Threads are more efficient, but they are also more prone to race conditions.
#
# 2. What is the difference between a kernel and a userspace?
#
# The kernel is the core of the operating system, and it is responsible for managing the hardware and providing basic services to userspace programs. Userspace programs are the applications that you run on your computer, and they interact with the kernel through a set of system calls.
#
# 3. What is the difference between a file system and a volume?
#
# A file system is a way of organizing data on a storage device, while a volume is a logical unit of storage that can be mounted on a file system. A volume can be a physical disk, a partition, or a logical drive.
#
# 4. What is the difference between a local and a network file system?
#
# A local file system is a file system that is stored on a local disk, while a network file system is a file system that is stored on a remote server. Network file systems allow you to access files that are stored on a remote computer as if they were stored on your local computer.
#
# 5. What is the difference between a shared and a non-shared file system?
#
# A shared file system is a file system that can be accessed by multiple users at the same time, while a non-shared file system is a file system that can only be accessed by one user at a time. Shared file systems are typically used for applications that need to be accessed by multiple users, such as databases and web servers.
#
# 6. What is the difference between a read-only and a read-write file system?
#
# A read-only file system is a file system that can only be read from, while a read-write file system can be both read from and written to. Read-only file systems are typically used for applications that need to be accessed by multiple users, but that do not need to be updated, such as backups and archives.
#
# 7. What is the difference between a compressed and an uncompressed file system?
#
# A compressed file system is a file system that stores data in a compressed format, while an uncompressed file system stores data in its original format. Compressed file systems are typically used to save space, but they can also be used to improve performance.
#
# 8. What is the difference between a journaling and a non-journaling file system?
#
# A journaling file system is a file system that keeps a record of all changes that are made to the file system, while a non-journaling file system does not keep a record of changes. Journaling file systems are typically used for applications that need to be highly available, such as databases and web servers.
#
# 9. What is the difference between a transactional and a non-transactional file system?
#
# A transactional file system is a file system that ensures that all changes are made atomically, or not at all, while a non-transactional file system does not guarantee atomicity. Transactional file systems are typically used for applications that need to be highly reliable, such as databases and financial systems.
#
# 10. What is the difference between a synchronous and an asynchronous file system?
#
# A synchronous file system is a file system that writes data to the disk immediately, while an asynchronous file system writes data to the disk in the background. Synchronous file systems are typically used for applications that need to be highly reliable, such as databases and financial systems. Asynchronous file systems are typically used for applications that need to be highly performant, such as web servers and email servers.
# None
# 1. What is the difference between a git branch and a git tag?
#
# A git branch is a line of development. It is a lightweight movable pointer to a commit. A git tag is a lightweight object that marks a specific commit in the history of a Git repository.
#
# 2. What is the difference between a git pull and a git fetch?
#
# A git pull is a combination of a git fetch and a git merge. A git fetch updates the local repository with changes from the remote repository, but does not merge them into the current branch. A git merge merges changes from the remote repository into the current branch.
#
# 3. What is the difference between a git push and a git push --force?
#
# A git push updates the remote repository with changes from the local repository. A git push --force updates the remote repository with changes from the local repository, even if there are conflicts.
#
# 4. What is the difference between a git commit and a git reset?
#
# A git commit creates a new commit in the history of a Git repository. A git reset discards changes made to the current branch.
#
# 5. What is the difference between a git add and a git commit?
#
# A git add adds changes to the staging area. A git commit creates a new commit in the history of a Git repository, using the changes in the staging area.
#
# 6. What is the difference between a git checkout and a git reset?
#
# A git checkout switches to a different branch. A git reset discards changes made to the current branch.
#
# 7. What is the difference between a git clone and a git pull?
#
# A git clone creates a local copy of a remote repository. A git pull updates the local repository with changes from the remote repository.
#
# 8. What is the difference between a git log and a git diff?
#
# A git log shows the history of a Git repository. A git diff shows the changes between two commits.
#
# 9. What is the difference between a git status and a git branch?
#
# A git status shows the current state of the local repository. A git branch shows the current branch and the branches that are available.
#
# 10. What is the difference between a git merge and a git rebase?
#
# A git merge merges changes from another branch into the current branch. A git rebase replays the changes from another branch on top of the current branch.
#
# 11. What is the difference between a git tag and a git branch?
#
# A git tag is a lightweight object that marks a specific commit in the history of a Git repository. A git branch is a line of development. It is a lightweight movable pointer to a commit.
#
# 12. What is the difference between a git stash and a git reset?
#
# A git stash saves the current state of the working directory and the index. A git reset discards changes made to the current branch.
#
# 13. What is the difference between a git archive and a git export?
#
# A git archive creates a compressed archive of a Git repository. A git export creates a tarball of a Git repository.
#
# 14. What is the difference between a git submodule and a git subfolder?
#
# A git submodule is a directory that contains a Git repository. A git subfolder is a directory that is not a Git repository.
#
# 15. What is the difference between a git remote and a git branch?
#
# A git remote is a pointer to a Git repository. A git branch is a line of development. It is a lightweight movable pointer to a commit.
#
# 16. What is the difference between a git remote add and a git remote update?
#
# A git remote add adds a new remote to the local repository. A git remote update updates the information about all remotes in the local repository.
#
# 17. What is the difference between a git remote prune and a git remote rm?
#
# A git remote prune removes remotes that are no longer used. A git remote rm removes a remote from the local repository.
#
# 18. What is the difference between a git config and a git alias?
#
# A git config sets a global or local configuration option. A git alias creates a shortcut for a command.
#
# 19. What is the difference between a git hook and a git filter?
#
# A git hook is a script that is executed before or after a Git operation. A git filter is a script that is used to transform the contents of a file.
#
# 20. What is the difference between a git difftool and a git mergetool?
#
# A git difftool is a tool that is used to compare two versions of a file. A git mergetool is a tool that is used to merge changes from two branches.
# Sure, here are two hard level interview questions about HTML, along with the correct answer immediately after each question:
#
# 1. What is the difference between a block element and an inline element?
#
# A block element is an element that takes up the full width of its parent element, while an inline element is an element that takes up only as much space as its content. For example, a paragraph is a block element, while a word is an inline element.
#
# 2. What is the difference between a text node and a comment node?
#
# A text node is a node that contains text, while a comment node is a node that contains a comment. Comments are ignored by the browser, but they can be used to provide information about the code.
#
# Here are some additional details about the answers to these questions:
#
# * Block elements are elements that take up the full width of their parent element. This means that if you have a paragraph inside of a div, the paragraph will take up the full width of the div.
# * Inline elements are elements that take up only as much space as their content. This means that if you have a word inside of a div, the word will only take up as much space as the word itself.
# * Text nodes are nodes that contain text. This means that if you have a paragraph, the paragraph will be a text node.
# * Comment nodes are nodes that contain comments. Comments are ignored by the browser, but they can be used to provide information about the code. For example, you might use a comment to explain what a particular piece of code does.
# 1. What is the difference between a process and a thread?
#
# A process is a heavyweight object that has its own address space, while a thread is a lightweight object that shares the address space of its parent process. Processes are more expensive to create and manage than threads, but they offer more isolation and security. Threads are more efficient, but they can be more difficult to debug and manage.
#
# 2. What is the difference between a fork and a clone system call?
#
# A fork system call creates a copy of the current process, while a clone system call creates a new process with a different address space. Fork is a more efficient system call than clone, but it does not offer the same level of flexibility. Clone is more flexible than fork, but it is also more expensive.
#
# 3. What is the difference between a shared library and a dynamic library?
#
# A shared library is a library that is shared by multiple processes, while a dynamic library is a library that is loaded into each process that uses it. Shared libraries are more efficient than dynamic libraries, but they can be more difficult to debug and manage. Dynamic libraries are more flexible than shared libraries, but they are also more expensive.
#
# 4. What is the difference between a semaphore and a mutex?
#
# A semaphore is a synchronization primitive that can be used to control access to a shared resource, while a mutex is a synchronization primitive that can be used to control access to a critical section of code. Semaphores are more general-purpose than mutexes, but they can be more difficult to use correctly. Mutexes are simpler to use than semaphores, but they are also less flexible.
#
# 5. What is the difference between a pipe and a socket?
#
# A pipe is a unidirectional communication channel between two processes, while a socket is a bidirectional communication channel between two processes. Pipes are more efficient than sockets, but they are also less flexible. Sockets are more flexible than pipes, but they are also more expensive.
#
# 6. What is the difference between a regular file and a device file?
#
# A regular file is a file that contains data, while a device file is a file that represents a physical device. Regular files are more common than device files, but device files are necessary for accessing physical devices.
#
# 7. What is the difference between a block device and a character device?
#
# A block device is a device that stores data in blocks, while a character device is a device that stores data as a stream of characters. Block devices are more common than character devices, but character devices are necessary for accessing some types of devices.
#
# 8. What is the difference between a file system and a partition?
#
# A file system is a logical organization of data on a storage device, while a partition is a physical division of a storage device. File systems are more common than partitions, but partitions are necessary for storing multiple file systems on a single storage device.
#
# 9. What is the difference between ext4 and btrfs?
#
# Ext4 is a journaling file system, while btrfs is a copy-on-write file system. Ext4 is more mature and stable than btrfs, but btrfs offers more features and flexibility.
#
# 10. What is the difference between LVM and RAID?
#
# LVM is a logical volume management system, while RAID is a redundant array of independent disks. LVM is more flexible than RAID, but RAID offers better performance and reliability.
